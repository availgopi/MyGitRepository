# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name):
    print("Hello, " + name)


####Solution: colon(:) is missing at end of function. Adding colon will fix the issue

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + str(age) + " years old")

####Solution: Cannot concanecate the int, conver the age to str (str(age)) wil fix the issue
# Out:
# I am 25 years old

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
    print(message)
    
greet()

####Solution: In print greet() function is not called, 
#also there is no print or return statement inside the greet() function
# Out:
# Object `code` not found.
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5,6))

###Solution: The function add passing only one argument whereas the function takes two arguments
# Out:
# 11

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False
####Solution: No error with code but logic needs to be changed. n % 2 == 0 for even numbers or swap the return statements

# %%
#6.What happens when you run this code?

num = int("10")
print(num)

####Solution: Cannot convert both int and char together, remove a will fix the issue
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)

####Solution: After sort() cannot use reverse(). Place the reverse() in separate line to fix
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers.append(4)
print(numbers)

###Solution: After appending it assign again to the list, need not assign it will automatically append the value
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10

def increment():
    global count
    count += 1
    print(count)

increment()

####Solution: variable count is declared outside the increment function, declare global count inside function to fix the issue
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])


###Solution: Index out of range
