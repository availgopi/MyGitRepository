# %%
print("HOPE AI")

# %%
instName = input("Enter you institute name : ")

# %%
input("Enter your name: ")
input("Enter your age: ")
input("Enter your school name: ")
input("Enter your degree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru School
# Enter your degree:  B.E. CSE
# 'B.E. CSE'

# %%
a = int(input("a "))
b = int(input("b "))
print("add ", a+b)
# Out:
# a  43
# b  34
# add  77

# %%
a = int(input("a "))
b = int(input("b "))
print("sub ", a-b)
# Out:
# a  43
# b  34
# sub  9

# %%
a = int(input("a "))
b = int(input("b "))
print("Mul ", a*b)
# Out:
# a  63
# b  97
# Mul  6111

# %%
a = int(input("a "))
b = int(input("b "))
print("float division ", a / b)
# Out:
# a  76
# b  31
# float division  2.4516129032258065

# %%
a = int(input("a "))
b = int(input("b "))
print("floor division ", a // b)
# Out:
# a  76
# b  31
# floor division  2

# %%
a = int(input("a "))
b = int(input("b "))
print("Power ", a ** b)
# Out:
# a  4
# b  4
# Power  256
