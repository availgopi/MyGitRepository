# %%
1. #1.
Q1. Create a DataFrame with the following student marks and display students with marks above 80.
{'Name': ['Anu', 'Raj', 'Diya', 'Kiran'], 'Marks': [76, 88, 95, 65]}

expected Output:
    
    Name  Marks
1   Raj     88
2  Diya     95

# %% [markdown]
# ## Solution

# %%
import pandas as pd
dataset = {
            'Name': ['Anu', 'Raj', 'Diya', 'Kiran'], 
           'Marks': [76, 88, 95, 65]
          }

dataset = pd.DataFrame(dataset)
res = dataset[dataset['Marks'] > 80]
print(res)
# Out:
#    Name  Marks
# 1   Raj     88
# 2  Diya     95

# %%
#2.Q2. Create a DataFrame and find the mean salary grouped by department.
{'Name': ['Amit', 'Sneha', 'Kunal', 'Riya'], 'Department': ['HR', 'IT', 'HR', 'IT'], 'Salary': [30000, 50000, 35000, 52000]}
Expected Output:
Department
HR    32500.0
IT    51000.0
Name: Salary, dtype: float64

# %% [markdown]
# ## Solution

# %%
#2.Q2. Create a DataFrame and find the mean salary grouped by department.
dataset={'Name': ['Amit', 'Sneha', 'Kunal', 'Riya'],
         'Department': ['HR', 'IT', 'HR', 'IT'], 
         'Salary': [30000, 50000, 35000, 52000]
        }
dataset = pd.DataFrame(dataset)
sal_mean = dataset.groupby(('Department'))['Salary'].mean()
print(sal_mean)
# Out:
# Department
# HR    32500.0
# IT    51000.0
# Name: Salary, dtype: float64

# %%
#3.Q3. Create a DataFrame and apply label encoding to the Gender column.
{'Name': ['Arjun', 'Leela', 'Kiran'], 'Gender': ['Male', 'Female', 'Male']}
Expected Output:
    Name  Gender  Gender_encoded
0  Arjun    Male               1
1  Leela  Female               0
2  Kiran    Male               1

# %% [markdown]
# ## Solution

# %%
#3.Q3. Create a DataFrame and apply label encoding to the Gender column.
dataset = {
            'Name': ['Arjun', 'Leela', 'Kiran'], 
           'Gender': ['Male', 'Female', 'Male']
        }
dataset = pd.DataFrame(dataset)
dataset
# Out:
#     Name  Gender
# 0  Arjun    Male
# 1  Leela  Female
# 2  Kiran    Male
