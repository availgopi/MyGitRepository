# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
Colon (:) is missing

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
Error: adding integer to string

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
missing colon (:)

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
Index values in numbers list must be 0 to 3. 4 is out of range

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
Missing braces

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
Division by zero

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
Trying to concanecate integar variable age with +, concanecate only possible with string. To make above code work replace + with ,

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
returns nothing as the step in range is negative (-1) and its forward counting

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
In if statement to compare values "=" used instead of "=="

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
Missing colon(:)
