# %%
# 1. Scenario: A system checks if a user is eligible to vote based on their age.
#Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.

# %%
age = int(input("Enter you age"))
if (age >= 18):
    print("Your are eligible for vote")
else:
    print("Your NOT eligible for vote")
# Out:
# Enter you age 33
# Your are eligible for vote

# %%
#2.	Scenario: A program processes a list of numbers and needs to find the largest value.
# Write logic to identify and return the largest number from a given list.

# %%
numbers = [50,20,105,80,14,96]
max_num = max(numbers)
print("The largest number in the list is :", max_num)
# Out:
# The largest number in the list is : 105

# %%
#3.	Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
# Write logic to determine the bonus amount based on the given salary.

# %%
sal = int(input("Enter the salary :"))
if(sal > 50000):
    bonus = int(sal * 0.10)
    print(f"The bonus for the salary ${sal} is ${bonus}")
else:
    print(f"The salary ${sal} is Not eligible for bonus")
# Out:
# Enter the salary : 66000
# The bonus for the salary $66000 is $6600

# %%
#4.	Scenario: A program evaluates a number to determine if it is even or odd.
#Write logic to check whether a given number is even or odd.

# %%
num = int(input("Enter the num"))
if(num % 2) == 1:
    print(f"the {num} is Odd")
else:
    print(f"the {num} is even")
# Out:
# Enter the num 25
# the 25 is Odd

# %%
#5.	Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
#Write logic to take a word or sentence as input and produce its reversed version.

# %%
words=input("Enter a word/sentence")
splitWords = words.split();
if len(splitWords) > 1:
    revW = splitWords[::-1]
    finRes = " ".join(revW)
    print(f"Reverse of sentence: '{finRes}'")
else:
    finRes=words[::-1]
    print(f"Reverse of word '{finRes}'")
# Out:
# Enter a word/sentence hellow
# Reverse of word 'wolleh'

# %%
words=input("Enter a word/sentence")
splitWords = words.split();
if len(splitWords) > 1:
    revW = splitWords[::-1]
    finRes = " ".join(revW)
    print(f"Reverse of sentence: '{finRes}'")
else:
    finRes=words[::-1]
    print(f"Reverse of word '{finRes}'")
# Out:
# Enter a word/sentence hello how are you
# Reverse of sentence: 'you are how hello'

# %%
#6.	Scenario: A grading system determines whether a student has passed or failed based on their score.
# Write logic to check if a student has passed a subject by scoring at least 40 marks.

# %%
score = int(input("Enter the score of any subject"))
if score >= 40:
    print("You are passed")
else:
    print("You are failed")
# Out:
# Enter the score of any subject 45
# You are passed

# %%
#7.	Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100. Write logic to calculate the final amount to be paid after applying the discount.

# %%
amt = int(input("Enter the amount of total order:"))
if(amt > 100):
    dis = amt * 0.20
    aftdis = amt - dis
print(f"Final amount after discount: {aftdis}")
# Out:
# Enter the amount of total order: 1000
# Final amount after discount: 800.0

# %%
#8.	Scenario: A banking system processes withdrawal requests and ensures the user has enough balance.
#Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.

# %%
actBal = float(input("Enter the Account Balance: "))
withAmt = float(input("Enter the Withdrawal Amount: "))
if withAmt > actBal:
    print("Insufficient Funds")
else:
    bal=actBal - withAmt
    print(f"The updated balance is {bal}")
# Out:
# Enter the Account Balance:  2000
# Enter the Withdrawal Amount:  500
# The updated balance is 1500.0

# %%
#9.Scenario: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
#Write logic to determine whether a given year is a leap year.

# %%
year = int(input("Enter a year: "))
if(year % 400 == 0) or (year % 4 == 0):
    print(f"The {year} is an Leap Year")
else:
    print(f"The {year} is not an Leap Year")
# Out:
# Enter a year:  2012
# The 2012 is an Leap Year

# %%
#10.	Scenario: A program filters out only even numbers from a given list.
#Write logic to extract and return only the even numbers from a list.

# %%
num = input("Enter numbers in comma separated: ")
splNum = num.split(',')
resEven = [int(item) for item in splNum if int(item) % 2 ==0 ]
print(f"The even numbers in the list are {resEven}")
# Out:
# Enter numbers in comma separated:  2,4,6,8,9,22,26
# The even numbers in the list are [2, 4, 6, 8, 22, 26]
