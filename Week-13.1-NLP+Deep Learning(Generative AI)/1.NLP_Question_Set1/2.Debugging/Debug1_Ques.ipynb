# %% [markdown]
# # 1.OS Error

# %%
import spacy
nlp = spacy_load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 import spacy
# ----> 2 nlp = spacy_load("en_core_web_sm")
#
# NameError: name 'spacy_load' is not defined

# %% [markdown]
# ## Solution 1

# %%
# Install spacy - pip install spacy
# Download English Model  !python -m spacy download en_core_web_sm

import spacy
nlp = spacy.load("en_core_web_sm") # change spacy_load to spacy.load
print(nlp)

# %% [markdown]
# # 2.Error: ModuleNotFoundError for TextBlob

# %%
from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from textblob import TextBlob
#       2 blob = TextBlob("TextBlob is amazing.")
#
# ModuleNotFoundError: No module named 'textblob'

# %% [markdown]
# ## Solution 2

# %%
# install textblob : !pip install textblob

from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)

# %% [markdown]
# # 3.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
texts = [123, 456]  # numeric values instead of strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 texts = [123, 456]  # numeric values instead of strings
#       3 vectorizer = CountVectorizer()
# ----> 4 X = vectorizer.fit_transform(texts)
#
# File ~\anaconda3\envs\GENAI\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\GENAI\Lib\site-packages\sklearn\feature_extraction\text.py:1386, in CountVectorizer.fit_transform(self, raw_documents, y)
# ...

# %% [markdown]
# ## Solution 3

# %%
# Convert numeric values to string before passing to CountVectorizer


from sklearn.feature_extraction.text import CountVectorizer
texts = ["123", "456"]  # numeric values instead of strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
print(X.toarray())
print(vectorizer.get_feature_names_out())
# Out:
# [[1 0]
#  [0 1]]
# ['123' '456']

# %% [markdown]
# # 4.Attribute Error

# %%
from nltk.corpus import stopwords
stop_words = stopwords.word('english')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 from nltk.corpus import stopwords
# ----> 2 stop_words = stopwords.word('english')
#
# File ~\anaconda3\envs\GENAI\Lib\site-packages\nltk\corpus\util.py:132, in LazyCorpusLoader.__getattr__(self, attr)
#     129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
# --> 132 return getattr(self, attr)
#
# AttributeError: 'WordListCorpusReader' object has no attribute 'word'

# %% [markdown]
# ## Solution 4

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english') # Replace word with words
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# # 5.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X = tfidf.fit_transform("single string instead of list")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 tfidf = TfidfVectorizer()
# ----> 3 X = tfidf.fit_transform("single string instead of list")
#
# File ~\anaconda3\envs\GENAI\Lib\site-packages\sklearn\feature_extraction\text.py:2104, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2097 self._check_params()
#    2098 self._tfidf = TfidfTransformer(
#    2099     norm=self.norm,
#    2100     use_idf=self.use_idf,
#    2101     smooth_idf=self.smooth_idf,
#    2102     sublinear_tf=self.sublinear_tf,
#    2103 )
# -> 2104 X = super().fit_transform(raw_documents)
#    2105 self._tfidf.fit(X)
#    2106 # X is already a transformed view of raw_documents so
#    2107 # we set copy to False
#
# ...

# %% [markdown]
# ## Solution 5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
doc = ["single string instead of list"]
X = tfidf.fit_transform(doc) # Pass as array instead fo string
print(X.toarray)
print(tfidf.get_feature_names_out())
# Out:
# <bound method _cs_matrix.toarray of <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (1, 5)>>
# ['instead' 'list' 'of' 'single' 'string']

# %% [markdown]
# # 6.NameError

# %%
from wordcloud import WordCloud
wc = WordCloud(stopwords=STOPWORDS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from wordcloud import WordCloud
# ----> 2 wc = WordCloud(stopwords=STOPWORDS)
#
# NameError: name 'STOPWORDS' is not defined

# %% [markdown]
# ## Solution 6

# %%
from wordcloud import WordCloud, STOPWORDS #STOPWORDS was missing. Add STOPWORDS in the import statement
import matplotlib.pyplot as plt

text = "NLP NLP is the AI Machine Learning Deep Learning AI"

wc = WordCloud(stopwords=STOPWORDS).generate(text)

plt.imshow(wc)
plt.axis("off")
plt.show()
