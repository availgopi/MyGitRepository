# %%
#1. Square of Numbers from 1 to 5
#Output:
#1 4 9 16 25

res = [ x**2 for x in range(1,6)]
print(res)
# Out:
# [1, 4, 9, 16, 25]

# %%
#2.Swap Two Variables Without Using a Temporary Variable
#Question: Write a Python program to swap two variables a = 5 and b = 10 without using a temporary variable.

a , b = 5, 10
a = a + b   # 15
b = a - b   # 15 - 10 = 5
a = a - b # 15 - 5 = 10

print( a, b)
# Out:
# 10 5

# %%
 #3.Find Even and Odd Numbers in a List
#Question: Write a Python program to separate even and odd numbers from the list [12, 17, 19, 24, 35, 40, 56].

lt = [12, 17, 19, 24, 35, 40, 56]
evenList = []
oddList = []
for num in lt:
    if num % 2 == 0:
        evenList.append(num)
    else:
        oddList.append(num)

print("The even number list are : ", evenList)
print("The Odd number list are : ", oddList)
# Out:
# The even number list are :  [12, 24, 40, 56]
# The Odd number list are :  [17, 19, 35]

# %%
#4. Reverse a Number
#Question: Write a Python program to reverse the number 12345.

num = 12345
a = str(num)[::-1]
print(f"The reverse of the number is  {a}")
# Out:
# The reverse of the number is  54321

# %%
#5. Find the Second Largest Number in a List
#Question: Write a Python program to find the second largest number in the list [12, 45, 98, 34, 23].

numlst = [12, 45, 98, 34, 23]
srtlst = sorted(numlst)
secLa = srtlst[-2]
print("The second largest number in give list is : " , secLa)
# Out:
# The second largest number in give list is :  45
