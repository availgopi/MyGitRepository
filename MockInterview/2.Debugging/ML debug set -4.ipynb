# %%
#1.
from sklearn.preprocessing import LabelEncoder
df['gender'] = LabelEncoder().fit_transform(df.gender)
df = pd.get_dummies(df, columns=['gender'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #1.
#       2 from sklearn.preprocessing import LabelEncoder
# ----> 3 df['gender'] = LabelEncoder().fit_transform(df.gender)
#       4 df = pd.get_dummies(df, columns=['gender'])
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Solution

# %%
#Dataset is missing
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("Problem statement")  # Add problem statement and create dataset

df['gender'] = LabelEncoder().fit_transform(df.gender)
df = pd.get_dummies(df, columns=['gender'])

# %%
#2.
from sklearn.tree import DecisionTreeClassifier
X = [1]
y = ['yes', 'no', 'yes', 'no']
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       4 y = ['yes', 'no', 'yes', 'no']
#       5 model = DecisionTreeClassifier()
# ----> 6 model.fit(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     993 @_fit_context(prefer_skip_nested_validation=True)
#     994 def fit(self, X, y, sample_weight=None, check_input=True):
# ...

# %%
#3.
X = data.drop('Purchased', axis=1)
y = data['Purchased']
X = X.drop('Purchased', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #3.
# ----> 2 X = data.drop('Purchased', axis=1)
#       3 y = data['Purchased']
#       4 X = X.drop('Purchased', axis=1)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Solution

# %%
# Dataset is missing 
import pandas as pd

data = pd.read_csv("Problemstatement") #Add problem statement and create dataset
X = data.drop('Purchased', axis=1)
y = data['Purchased']
X = X.drop('Purchased', axis=1)

# %%
#4.
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=None)  
model.fit(X, y)

model.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       2 from sklearn.tree import DecisionTreeClassifier
#       4 model = DecisionTreeClassifier(max_depth=None)
# ----> 5 X=X.reshape(-1, 1)
#       7 model.fit(X, y)
#       9 model.score(X, y)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
#5.
from sklearn.preprocessing import MinMaxScaler
import numpy as np

data = [[-1, 2], [0, 0], [1, 2]]
scaler = MinMaxScaler()
scaler.fit(data)
print(scaler.transform())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       6 scaler = MinMaxScaler()
#       7 scaler.fit(data)
# ----> 8 print(scaler.transform())
#
# TypeError: MinMaxScaler.transform() missing 1 required positional argument: 'X'

# %% [markdown]
# ## Solution

# %%
#5.
from sklearn.preprocessing import MinMaxScaler
import numpy as np

data = [[-1, 2], [0, 0], [1, 2]]
scaler = MinMaxScaler()
scaler.fit(data)
print(scaler.transform(data)) # Parameter is missing, add data
# Out:
# [[0.  1. ]
#  [0.5 0. ]
#  [1.  1. ]]

# %%
#6.
from sklearn.metrics import accuracy_score

y_true = [1, 0, 1]
y_pred = [1, 1, 0]

acc = accuracy_score()
print("Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       4 y_true = [1, 0, 1]
#       5 y_pred = [1, 1, 0]
# ----> 7 acc = accuracy_score(y_true)
#       8 print("Accuracy:", acc)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File ~\anaconda3\Lib\inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
# ...

# %% [markdown]
# ## Solution

# %%
#6.
from sklearn.metrics import accuracy_score

y_true = [1, 0, 1]
y_pred = [1, 1, 0]

acc = accuracy_score(y_true,y_pred) # missing parameters
print("Accuracy:", acc)
# Out:
# Accuracy: 0.3333333333333333

# %%
#7.
from sklearn.model_selection import train_test_split
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])
y = np.array([0, 1])

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 8
#       5 X = np.array([[1, 2], [3, 4], [5, 6]])
#       6 y = np.array([0, 1])
# ----> 8 X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
# ...

# %% [markdown]
# ## Solution

# %%
#7.
from sklearn.model_selection import train_test_split
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])
y = np.array([0, 1, 2])

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#8.
import pandas as pd

df = pd.DataFrame({
    'Feature': ['1', '2', 'three']
})

df['Feature'] = df['Feature'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 8
#       2 import pandas as pd
#       4 df = pd.DataFrame({
#       5     'Feature': ['1', '2', 'three']
#       6 })
# ----> 8 df['Feature'] = df['Feature'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %% [markdown]
# ## Solution

# %%
#8.
import pandas as pd

df = pd.DataFrame({
    'Feature': ['1', '2', '3'] # change to numeric letter 3 from three

    # Or
 })  

df['Feature'] = df['Feature'].astype(int)

# %%
#9
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = ['yes', 'no'] 
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 7
#       5 y = ['yes', 'no']
#       6 clf = DecisionTreeClassifier()
# ----> 7 clf.fit(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     993 @_fit_context(prefer_skip_nested_validation=True)
#     994 def fit(self, X, y, sample_weight=None, check_input=True):
# ...

# %% [markdown]
# ## Solution

# %%
#9
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = ['yes', 'no', 'neutral'] 
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
#10.
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

iris = load_iris()
X, y = iris.data, iris.target

model = LogisticRegression()
model.fit(X, y)
print(model.predict_proba([[5.1, 3.5]]))
# Out:
# C:\Users\kgopi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 10
#       8 model = LogisticRegression()
#       9 model.fit(X, y)
# ---> 10 print(model.predict_proba([[5.1, 3.5]]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1430, in LogisticRegression.predict_proba(self, X)
#    1428     return super()._predict_proba_lr(X)
# ...

# %% [markdown]
# ## Solution

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

iris = load_iris()
X, y = iris.data, iris.target

model = LogisticRegression()
model.fit(X, y)
print(model.predict_proba([[5.1, 3.5, 2.6, 4.7]]))
# Out:
# [[0.08987919 0.0503257  0.8597951 ]]
# C:\Users\kgopi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
